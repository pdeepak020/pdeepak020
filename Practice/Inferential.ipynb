# %% [markdown]
# # inferential

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # central limit Theorm

# %%
w=np.random.randn(85000)
#w=np.random.uniform(size=85000)

# %%
sns.distplot(w)
# Out:
# /tmp/ipykernel_249/2796295718.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(w)
# <AxesSubplot: ylabel='Density'>

# %%
w.max(),w.min()
# Out:
# (4.150767717941462, -4.152091095624484)

# %%
w.mean()
# Out:
# 0.0004070257549767222

# %%
w[0:100]
# Out:
# array([ 0.72706295, -1.24585841, -0.38686321, -0.97299682,  0.30992452,
#         1.30061478,  0.14647512,  0.42502185, -0.08713054,  0.42577746,
#         1.10608917, -1.12742728,  0.74505   , -1.16172692,  0.16399185,
#         1.3998528 ,  1.03069269, -0.66243803, -0.03707679,  0.23940646,
#        -1.50318508,  0.11933488,  0.45200931,  0.90949931, -0.57083295,
#        -1.1499249 ,  0.70933007,  1.83346367, -2.24349734,  0.38350607,
#        -0.1845763 , -0.53771554, -0.11288119,  0.29255904,  0.85363784,
#         1.56085903, -0.60451057, -0.56649981, -1.32095595,  2.08664801,
#        -0.32224523, -0.58094015, -1.28760692, -0.74515907,  0.39357426,
#        -1.48310816, -1.35847814,  0.50651292, -0.55806622, -1.35589279,
#         0.25976077, -1.12677349,  0.01280555, -0.50779115, -0.37159639,
#         0.44315567,  1.28831074, -1.21723627, -1.38782419, -1.11846256,
#         0.84718723, -0.89870653,  1.41081016,  0.90216101,  0.62610296,
# ...

# %%
# The average weight of new born baby - 3 Kg with the sd of 0.8

# %%
w_pop=w*0.8 + 3

# %%
w_pop
# Out:
# array([3.58165036, 2.00331327, 2.69050943, ..., 3.82278568, 2.61196586,
#        4.36843955])

# %%
w_pop.max(),w_pop.min()
# Out:
# (6.320614174353169, -0.3216728764995871)

# %%
w_pop[0:100]
# Out:
# array([3.58165036, 2.00331327, 2.69050943, 2.22160254, 3.24793962,
#        4.04049182, 3.1171801 , 3.34001748, 2.93029557, 3.34062197,
#        3.88487134, 2.09805818, 3.59604   , 2.07061846, 3.13119348,
#        4.11988224, 3.82455415, 2.47004957, 2.97033857, 3.19152517,
#        1.79745193, 3.0954679 , 3.36160745, 3.72759945, 2.54333364,
#        2.08006008, 3.56746406, 4.46677093, 1.20520213, 3.30680486,
#        2.85233896, 2.56982757, 2.90969505, 3.23404723, 3.68291028,
#        4.24868723, 2.51639154, 2.54680015, 1.94323524, 4.66931841,
#        2.74220382, 2.53524788, 1.96991446, 2.40387274, 3.31485941,
#        1.81351347, 1.91321749, 3.40521034, 2.55354702, 1.91528577,
#        3.20780862, 2.09858121, 3.01024444, 2.59376708, 2.70272289,
#        3.35452454, 4.03064859, 2.02621099, 1.88974065, 2.10522995,
#        3.67774979, 2.28103478, 4.12864813, 3.72172881, 3.50088237,
#        2.04137033, 3.10494749, 3.02766902, 2.96459396, 1.65947882,
# ...

# %%
w_pop.mean()
# Out:
# 3.0003256206039817

# %%
sns.boxplot(w_pop)
# Out:
# <AxesSubplot: >

# %%
#classical
trial=[]
for i in np.arange(100):    
    samp=[]
    for val in np.arange(500):
        samp.append(np.random.choice(w_pop))
    trial.append(np.mean(samp))

# %%
len(trial)
# Out:
# 100

# %%
sns.distplot(trial)
# Out:
# /tmp/ipykernel_249/389314477.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(trial)
# <AxesSubplot: ylabel='Density'>

# %%
import pandas as pd
pd.Series(trial).skew()
# Out:
# 0.1375442913583224

# %%
me=np.array(trial).mean()
me
# Out:
# 2.9988337417252326

# %%
s_d=np.array(trial).std()
s_d
# Out:
# 0.038131560719043944

# %%
me-3*(s_d),me+3*(s_d) # 99.7 percentage of data lie in this limit
# Out:
# (2.8844390595681006, 3.1132284238823646)

# %%
me-2*(s_d),me+2*(s_d) # 95.5 percentage of data lie in this limit
# Out:
# (2.9225706202871446, 3.0750968631633206)

# %%
#What is the data range for 95 percent of data ?
me-1.96*(s_d),me+1.96*(s_d) # 95 percentage of data lie in this limit
# Out:
# (2.9240958827159065, 3.073571600734559)

# %%
# Method 2-----Practical
ss=[]
for i in np.arange(500):
    ss.append(np.random.choice(w_pop))

# %%
len(ss)
# Out:
# 500

# %%
x_bar=np.mean(ss)
x_bar
# Out:
# 2.984227915408471

# %%
#increase the sample size reduce the sample mean error
std_err=np.std(ss)/np.sqrt(500)

# %%
#What is the data range for 95 percent of data ?
x_bar-1.96*std_err,x_bar+1.96*std_err
# Out:
# (2.9161820675944177, 3.0522737632225243)

# %%
from scipy import stats

# %%
stats.norm.isf(0.025)
# Out:
# 1.9599639845400545

# %%
stats.norm.isf(0.050)
# Out:
# 1.6448536269514729

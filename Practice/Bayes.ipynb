# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # What is probability of employee leaving the organization given that he is working in sales department?

# %% [markdown]
# # What is probability of employee leaving the organization given that he is working in sales department and travelling frequently?

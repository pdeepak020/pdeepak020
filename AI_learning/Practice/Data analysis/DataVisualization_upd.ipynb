# %%
# Data visualization

# matplotlib

# seaborn

# %%
# univariant------get the inference with single column (histogram,boxplot,countplot)

# bivariant------->get the inference with 2variable(line plot,scatterplot,barchart,pierchart,heatmap)

# multivariant------>get the inferenec from more than 2 variable (pairplot,jointplot)

# %%
# lineplot

# scatterplot

# barplot

# pie chart

# histogram

# countplot

# boxplot

# violinplot

# stripplot

# swarmplot

# heatmap

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# import warnings
# warnings.filterwarnings("ignore")

# %%
t=np.linspace(0,20,10)
t
# Out:
# array([ 0.        ,  2.22222222,  4.44444444,  6.66666667,  8.88888889,
#        11.11111111, 13.33333333, 15.55555556, 17.77777778, 20.        ])

# %%
y=np.sin(t)
y
# Out:
# array([ 0.        ,  0.79522006, -0.96431712,  0.37415123,  0.51060568,
#        -0.99333304,  0.69395153,  0.15181837, -0.87805285,  0.91294525])

# %%
#lineplot
plt.plot(t,y)
plt.show()

# %%
y1=np.cos(t)
plt.plot(t,y1)
plt.show()

# %%
y2=np.tan(t)
plt.plot(t,y2)
plt.show()

# %%
plt.plot(t,y,color="r",marker="*",label="sinwave")
plt.plot(t,y1,color="g",label="coswave")
plt.plot(t,y2,color="m",label="tanwave")
plt.legend()# to print the label
plt.show()

# %%
# subplot
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
plt.plot(t,y,color="r",marker="*",label="sinwave")
plt.legend()

plt.subplot(2,2,2)
plt.plot(t,y1,color="g",label="coswave")
plt.legend()


plt.subplot(2,2,3)
plt.plot(t,y2,color="m",label="tanwave")
plt.legend()

plt.subplot(2,2,4)
plt.plot(t,y2,color="c",label="wave")
plt.legend()
plt.show()

# %%
#sactterplot
plt.scatter(t,y)
plt.show()

# %%
plt.bar(t,y)
plt.show()

# %%
#Barchart------->bivariant plot (1 numeric, 1 category)
x=["A","B","C","D"]
y=[24,67,12,89]
plt.bar(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
#histogram(data distribution)-------->univariant

data=np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
#data

# %%
# piechart------->bivariant ( 1numerical and 1 categorical)# percentage distribution
agent=["John","Kumar","ben","Dev","giri"]
loan=[24,18,29,7,32]
#plt.bar(agent,loan)
plt.pie(loan,labels=agent,autopct="%.1f",explode=[0,0,0,0,0.3])
plt.show()

# %% [markdown]
# # seaborn

# %%
import seaborn as sns
sns.get_dataset_names() #get different datasets in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data1=sns.load_dataset('tips')
data1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
#find the relation between total bill and tips
plt.figure(figsize=(10,5))
sns.lineplot(x=data1["total_bill"],y=data1["tip"])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=data1["total_bill"],y=data1["tip"],hue=data1["sex"])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=data1["total_bill"],y=data1["tip"],hue=data1["time"])
plt.show()

# %%
#barplot(1 numerical,categorical)
# what is the max amount of bills paid by male and female
sns.barplot(x=data1["sex"],y=data1["total_bill"],ci=None,estimator=np.max,hue=data1["time"])
plt.show()
# Out:
# C:\Users\Deepak Pandey\AppData\Local\Temp\ipykernel_22412\836973540.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=data1["sex"],y=data1["total_bill"],ci=None,estimator=np.max,hue=data1["time"])

# %%
data1.groupby("sex")["total_bill"].mean()
# Out:
# C:\Users\Deepak Pandey\AppData\Local\Temp\ipykernel_22412\3469469985.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data1.groupby("sex")["total_bill"].mean()
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
sns.barplot(x=data1["time"],y=data1["tip"],ci=None,estimator=np.max,hue=data1["day"])
plt.show()
# Out:
# C:\Users\Deepak Pandey\AppData\Local\Temp\ipykernel_22412\2565358616.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=data1["time"],y=data1["tip"],ci=None,estimator=np.max,hue=data1["day"])

# %%
data1["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
sns.countplot(x=data1["day"])
plt.show()

# %%
#statistical plot

# Heatmap--------->correlation analysis(multivariant)

# boxplot-----------> outlier detection

# Violin plot---------->another representaion of outlier treatment

# %%
# correlation analysis(only for numerical)

data1.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data1.corr(numeric_only=True),annot=True,cmap="coolwarm")
plt.show()

# %%
# boxplot(outlier detection)
sns.boxplot(x=data1["total_bill"])
plt.show()

# %%
data1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#total bill

q1=13.34

q3=24.12

iqr= q3-q1

lb=q1-1.5*iqr

ub=q3+1.5*iqr

print("LB:" ,lb, "UB:",ub)
# Out:
# LB: -2.830000000000002 UB: 40.290000000000006

# %%
sns.boxplot(x=data1["time"],y=data1["total_bill"],hue=data1["sex"])
plt.show()

# %%
#violinplot
sns.violinplot(x=data1["total_bill"])
plt.show()

# %%
sns.violinplot(x=data1["time"],y=data1["total_bill"],hue=data1["sex"])
plt.show()

# %%
#distribution plot# univariant plot( numerical data) kde-->kernal density estimator

sns.displot(data1["total_bill"],kde=False)
plt.show()

# %%
#
sns.displot(data1["total_bill"],kde=True)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
# What is probability of employee leaving the organization given that he is working in sales department?

# What is probability of employee leaving the organization given that he is working in sales department and travelling frequently?

# %%
data=pd.read_csv("HRdata.csv")
data.head(2)
# Out:
#    Unnamed: 0   Age Attrition     BusinessTravel Department  DistanceFromHome  \
# 0           0  33.0       Yes  Travel_Frequently        NaN               3.0
# 1           1   NaN       Yes      Travel_Rarely      Sales               4.0
#
#   EducationField  EnvironmentSatisfaction Gender  JobInvolvement  JobLevel  \
# 0  Life Sciences                        1   Male               3         1
# 1        Medical                        4   Male               1         3
#
#               JobRole  JobSatisfaction  MonthlyIncome  NumCompaniesWorked  \
# 0  Research Scientist              1.0         3348.0                   1
# 1     Sales Executive              4.0            NaN                   1
#
#   OverTime  PercentSalaryHike  PerformanceRating  YearsAtCompany
# 0      Yes                 11                  3              10
# 1       No                 11                  3              14

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                   0
# Age                        150
# Attrition                    0
# BusinessTravel             100
# Department                 175
# DistanceFromHome           180
# EducationField               0
# EnvironmentSatisfaction      0
# Gender                       0
# JobInvolvement               0
# JobLevel                     0
# JobRole                      0
# JobSatisfaction             40
# MonthlyIncome              120
# NumCompaniesWorked           0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# YearsAtCompany               0
# dtype: int64

# %%
data=data.dropna()# drop all teh missing value

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                 0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobRole                    0
# JobSatisfaction            0
# MonthlyIncome              0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# PerformanceRating          0
# YearsAtCompany             0
# dtype: int64

# %% [markdown]
# # What is probability of employee leaving the organization given that he is working in sales department?

# %%
data["Department"].unique()
# Out:
# array(['Research & Development', 'Human Resources', 'Sales'], dtype=object)

# %%
#P(Attriation=Yes/salesdepart) = (P(Sales depart/Attri=Yes)*P(Attriation=Yes)) / P(Sale_depart)

# %%
data["Department"].value_counts()
# Out:
# Research & Development    584
# Sales                     344
# Human Resources            42
# Name: Department, dtype: int64

# %%
data["Department"].value_counts(normalize=True)
# Out:
# Research & Development    0.602062
# Sales                     0.354639
# Human Resources           0.043299
# Name: Department, dtype: float64

# %%
data["Attrition"].value_counts(normalize=True)
# Out:
# No     552
# Yes    418
# Name: Attrition, dtype: int64

# %%
P(Sales)=0.354
P(Attriation=Yes) =0.430
P(Sales depart/Attri=Yes) =0.4258

# %%
data["Attrition"].value_counts(normalize=True)

# %%
data[data["Attrition"]=="Yes"]["Department"].value_counts(normalize=True)
# Out:
# Research & Development    0.523923
# Sales                     0.425837
# Human Resources           0.050239
# Name: Department, dtype: float64

# %%
data[data["Attrition"]=="Yes"]["Department"].value_counts(normalize=True)

# %%
(0.4258*0.430)/0.354
# Out:
# 0.5172146892655368

# %% [markdown]
# # What is probability of employee leaving the organization given that he is working in sales department and travelling frequently?

# %%
data["BusinessTravel"].unique()

# %%
#P(Attriation=Yes/salesdepart,travelFrequ) = (P(Sales depart/Attri=Yes) * P(freqtravel/Attri=Yes)  *P(Attriation=Yes)) / P(Sale_depart) * P(FreqTravel)

# %%
data["BusinessTravel"].value_counts(normalize=True)
# Out:
# Travel_Rarely        0.721649
# Travel_Frequently    0.200000
# Non-Travel           0.078351
# Name: BusinessTravel, dtype: float64

# %%
P(Sales)=0.354
P(Attriation=Yes) =0.430
P(Sales depart/Attri=Yes) =0.4258
P(freq_travel)=0.20
P(freqtravel/Attri=Yes) =0.260766

# %%
data[data["Attrition"]=="Yes"]["BusinessTravel"].value_counts(normalize=True)
# Out:
# Travel_Rarely        0.700957
# Travel_Frequently    0.260766
# Non-Travel           0.038278
# Name: BusinessTravel, dtype: float64

# %%
(0.4258* 0.260766*0.430)/(0.354*0.20)
# Out:
# 0.6743600283050848

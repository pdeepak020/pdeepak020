# %% [markdown]
# # sequence Datatype

# %% [markdown]
# List
#
# tuple
#
# set
#
# dictionary

# %% [markdown]
# # Lists

# %% [markdown]
# []---Declaration
#
# store multiple values(hetrogenous)
#
# it is mutable(changeable)
#
# it is ordered or indexed
#
# duplicate is allowed
#
# index is start with 0

# %%
a=[1,20,"Hi",7.5,"hello",100,20,True]
a[2]
print(a[:-2], a[-2:])
# Out:
# [1, 20, 'Hi', 7.5, 'hello', 100] [20, True]

# %%
a[0]
# Out:
# 1

# %%
a[1:5]
# Out:
# [20, 'Hi', 7.5, 'hello']

# %%
#update
a[0]="Welcome"
a
# Out:
# ['Welcome', 20, 'Hi', 7.5, 'hello', 100, 20, True]

# %%
a[0]=[10,20,30]
a
# Out:
# [[10, 20, 30], 20, 'Hi', 7.5, 'hello', 100, 20, True]

# %%
a[0][2]
# Out:
# 30

# %%
len(a)
# Out:
# 8

# %%
#add the element in the list
#append---------->add one element in list, it add the element at last
a.append("Cool")
print(a)
print(len(a))
# Out:
# [[10, 20, 30], 20, 'Hi', 7.5, 'hello', 100, 20, True, 'Cool']
# 9

# %%
#add more element
a.extend([1000,2000])
print(a)
print(len(a))
# Out:
# [[10, 20, 30], 20, 'Hi', 7.5, 'hello', 100, 20, True, 'Cool', 1000, 2000]
# 11

# %%
a.append([100,200])

# %%
print(a)
print(len(a))
# Out:
# [[10, 20, 30], 20, 'Hi', 7.5, 'hello', 100, 20, True, 'Cool', 1000, 2000, [100, 200]]
# 12

# %%
# add teh element in particular position
a.insert(1,"break")
print(a)
print(len(a))
# Out:
# [[10, 20, 30], 'break', 20, 'Hi', 7.5, 'hello', 100, 20, True, 'Cool', 1000, 2000, [100, 200]]
# 13

# %%
a.remove(20)
print(a)
print(len(a))
# Out:
# [[10, 20, 30], 'break', 'Hi', 7.5, 'hello', 100, 20, True, 'Cool', 1000, 2000, [100, 200]]
# 12

# %%
a.remove([10, 20, 30])
print(a)
print(len(a))
# Out:
# ['break', 'Hi', 7.5, 'hello', 100, 20, True, 'Cool', 1000, 2000, [100, 200]]
# 11

# %%
# remove the element based on Index
a.pop(2)
# Out:
# 'hello'

# %%
print(a)
print(len(a))
# Out:
# ['break', 'Hi', 'hello', 100, 20, True, 'Cool', 1000, 2000, [100, 200]]
# 10

# %%
a.pop(0)
print(a)
print(len(a))
# Out:
# ['Hi', 20]
# 2

# %% [markdown]
# # tuple

# %% [markdown]
# ()---Declaration
#
# store multiple values(hetrogenous)
#
# it is immutable(unchangeable)
#
# it is ordered or indexed
#
# duplicate is allowed
#
# index is start with 0

# %%
t=(10,"good",100,70.6,True,"Welcome")
print(t)
print(type(t))
# Out:
# (10, 'good', 100, 70.6, True, 'Welcome')
# <class 'tuple'>

# %%
t[0]
# Out:
# 10

# %%
t=list(t)
t[0]="hi"
t=tuple(t)
t
# Out:
# ('hi', 'good', 100, 70.6, True, 'Welcome')

# %%
a=10,20
a
# Out:
# (10, 20)

# %% [markdown]
# # set

# %% [markdown]
# {}------>Declaration
#
# store multiple values(hetrogenous)
#
# it is immutable(unchangeable)
#
# unindexing
#
# duplicate is not allowed

# %%
s={10,15,"hello",1,1.0,100,7.5,True,10,100,"True",0,False}
print(s)
print(type(s))
# Out:
# {0, 1, 100, 7.5, 'hello', 10, 15, 'True'}
# <class 'set'>

# %%
# intersection
#unioin
s1={10,20,30,40,50}
s2={100,200,40,30,50}
s1.intersection(s2)
# Out:
# {30, 40, 50}

# %%
s1.union(s2)
s1.intersection(s2)
# Out:
# {30, 40, 50}

# %% [markdown]
# # Dictionary
#
# {}--->declaration
#
# key:value pair
#
# value can be accessed based on key
#
# mutable is allowed
#
# it is not allowed duplicates

# %%
#dictionary
d={"Name":"John","Age":24,"Country":"US"}
print(type(d))
print(d)
# Out:
# <class 'dict'>
# {'Name': 'John', 'Age': 24, 'Country': 'US'}

# %%
d["Name"]
# Out:
# 'John'

# %%
d["Country"]="India"
d
# Out:
# {'Name': 'John', 'Age': 24, 'Country': 'India'}

# %%
d["gender"]="male"
d
# Out:
# {'Name': 'John', 'Age': 24, 'Country': 'India', 'gender': 'male'}

# %%
d1={'Name': 'John', 'Age': 24, 'Country': 'India', 'gender': 'male','Age':35}
d1
# Out:
# {'Name': 'John', 'Age': 35, 'Country': 'India', 'gender': 'male'}

# %%
d1["Age"]=20
d1
# Out:
# {'Name': 'John', 'Age': 20, 'Country': 'India', 'gender': 'male'}

# %%
l1=[10,20,30,40,50]
l2=[100,200,300,400,500]
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50]
# [100, 200, 300, 400, 500]

# %%
l1+l2
# Out:
# [10, 20, 30, 40, 50, 100, 200, 300, 400, 500]

# %%
for i in range(len(l1)):
    y=l1[i]+l2[i]
    print(y)
# Out:
# 110
# 220
# 330
# 440
# 550

# %%
# multiply l1 with 3
l1*3
# Out:
# [10, 20, 30, 40, 50, 10, 20, 30, 40, 50, 10, 20, 30, 40, 50]

# %%
for i in l1:
    z=i*3
    print(z)
# Out:
# 30
# 60
# 90
# 120
# 150

# %%
import numpy as np
n1=np.array(l1)
n2=np.array(l2)
n1+n2
# Out:
# array([110, 220, 330, 440, 550])

# %%
n1*3
# Out:
# array([ 30,  60,  90, 120, 150])

# %%
import time
result=[]
st=time.time()
l1=list(range(1,5000000))
l2=list(range(1,5000000))
for i in range(len(l1)):
    result.append(l1[i]+l2[i])
print("list time taken",(time.time()-st)*1000,"ms")
# Out:
# list time taken 646.4922428131104 ms

# %%
st1=time.time()
n1=np.array(l1)
n2=np.array(l2)
a=n1+n2
print("list time taken",(time.time()-st1)*1000,"ms")
# Out:
# list time taken 416.2285327911377 ms

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("demopic.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 img=cv2.imread("demopic.jpg")
#
# NameError: name 'cv2' is not defined

# %%
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 plt.imshow(img)
#
# File a:\Python\venv\Lib\site-packages\matplotlib\pyplot.py:3590, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3568 @_copy_docstring_and_deprecators(Axes.imshow)
#    3569 def imshow(
#    3570     X: ArrayLike | PIL.Image.Image,
#    (...)   3588     **kwargs,
#    3589 ) -> AxesImage:
# -> 3590     __ret = gca().imshow(
#    3591         X,
#    3592         cmap=cmap,
#    3593         norm=norm,
#    3594         aspect=aspect,
#    3595         interpolation=interpolation,
#    3596         alpha=alpha,
#    3597         vmin=vmin,
#    3598         vmax=vmax,
#    3599         colorizer=colorizer,
#    3600         origin=origin,
# ...

# %%
img.shape
# Out:
# (148, 148, 3)

# %%
img
# Out:
# array([[[  0,   9,   6],
#         [  0,   9,   6],
#         [  0,  10,   7],
#         ...,
#         [194, 199, 198],
#         [191, 196, 195],
#         [188, 193, 192]],
#
#        [[  0,   9,   6],
#         [  0,  10,   7],
#         [  0,  11,   8],
#         ...,
#         [193, 198, 197],
#         [190, 195, 194],
#         [187, 192, 191]],
#
#        [[  0,  10,   7],
#         [  0,  11,   8],
#         [  0,  13,   9],
#         ...,
#         [190, 196, 195],
#         [188, 194, 193],
#         [185, 191, 190]],
#
#        ...,
#
#        [[ 34,  96,  84],
#         [ 34,  96,  84],
#         [ 33,  95,  83],
#         ...,
#         [ 39,  89, 107],
#         [ 40,  88, 106],
#         [ 40,  88, 106]],
#
#        [[ 33,  95,  83],
#         [ 32,  94,  82],
#         [ 31,  93,  81],
#         ...,
#         [ 37,  88, 104],
#         [ 39,  88, 104],
#         [ 38,  87, 103]],
#
#        [[ 31,  93,  81],
#         [ 30,  92,  80],
#         [ 30,  92,  80],
# ...

# %%
demo=img+100

# %%
demo
# Out:
# array([[[100, 109, 106],
#         [100, 109, 106],
#         [100, 110, 107],
#         ...,
#         [ 38,  43,  42],
#         [ 35,  40,  39],
#         [ 32,  37,  36]],
#
#        [[100, 109, 106],
#         [100, 110, 107],
#         [100, 111, 108],
#         ...,
#         [ 37,  42,  41],
#         [ 34,  39,  38],
#         [ 31,  36,  35]],
#
#        [[100, 110, 107],
#         [100, 111, 108],
#         [100, 113, 109],
#         ...,
#         [ 34,  40,  39],
#         [ 32,  38,  37],
#         [ 29,  35,  34]],
#
#        ...,
#
#        [[134, 196, 184],
#         [134, 196, 184],
#         [133, 195, 183],
#         ...,
#         [139, 189, 207],
#         [140, 188, 206],
#         [140, 188, 206]],
#
#        [[133, 195, 183],
#         [132, 194, 182],
#         [131, 193, 181],
#         ...,
#         [137, 188, 204],
#         [139, 188, 204],
#         [138, 187, 203]],
#
#        [[131, 193, 181],
#         [130, 192, 180],
#         [130, 192, 180],
# ...

# %%
plt.imshow(demo)

# %%
1024*1024*3
# Out:
# 3145728

# %%
# Different methods in numpy

# %%
#creation of 1D array
np.random.seed(100)
x=np.random.randint(1,20,5)
print(x)
# Out:
# [ 9  4  8 16 17]

# %%
#rray([ 9, 16, 14,  9, 12]

# %%
x.ndim
# Out:
# 1

# %%
x.shape
# Out:
# (5,)

# %%
#creation of 2d array
np.random.seed(3)
x1=np.random.randint(1,25,(3,4))
x1
# Out:
# array([[11,  4,  9,  1],
#        [22, 20, 11, 12],
#        [10, 11, 22, 24]])

# %%
# reshaping
#arithmetic operation
#where
# argmax
# argmin
# min
# max

# %%
x1
# Out:
# array([[11,  4,  9,  1],
#        [22, 20, 11, 12],
#        [10, 11, 22, 24]])

# %%
x1.reshape(4,3)
# Out:
# array([[11,  4,  9],
#        [ 1, 22, 20],
#        [11, 12, 10],
#        [11, 22, 24]])

# %%
x1.reshape(6,2)
# Out:
# array([[11,  4],
#        [ 9,  1],
#        [22, 20],
#        [11, 12],
#        [10, 11],
#        [22, 24]])

# %%
x1
# Out:
# array([[11,  4,  9,  1],
#        [22, 20, 11, 12],
#        [10, 11, 22, 24]])

# %%
x1.reshape(-1,2)
# Out:
# array([[11,  4],
#        [ 9,  1],
#        [22, 20],
#        [11, 12],
#        [10, 11],
#        [22, 24]])

# %%
x1.reshape(4,-1)
# Out:
# array([[11,  4,  9],
#        [ 1, 22, 20],
#        [11, 12, 10],
#        [11, 22, 24]])

# %%
#arithmetic
x1
# Out:
# array([[11,  4,  9,  1],
#        [22, 20, 11, 12],
#        [10, 11, 22, 24]])

# %%
x1.sum()
# Out:
# 157

# %%
x1=np.random.randint(1,25,(3,4))
x1.sum(axis=1)# rowwise
x1.sum(axis=0)# columnwise
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x1=np.random.randint(1,25,(3,4))
#       2 x1.sum(axis=1)# rowwise
#       3 x1.sum(axis=0)# columnwise
#
# NameError: name 'np' is not defined

# %%
x1.mean()
# Out:
# 13.083333333333334

# %%
x1.std()
# Out:
# 7.041050268879557

# %%
x1.min()
# Out:
# 1

# %%
x1.max()
# Out:
# 24

# %%
x1.argmax()
# Out:
# 11

# %%
x1.argmin()
# Out:
# 3

# %%
x1
# Out:
# array([[11,  4,  9,  1],
#        [22, 20, 11, 12],
#        [10, 11, 22, 24]])

# %%
np.where(x1<=11,0,100)
# Out:
# array([[  0,   0,   0,   0],
#        [100, 100,   0, 100],
#        [  0,   0, 100, 100]])
